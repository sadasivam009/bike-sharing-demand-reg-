# %% [markdown]
# <a href="https://colab.research.google.com/github/sadasivam009/bike-sharing-demand-reg-/blob/main/reg_%5Bnew_york_city_%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  **• New York City Taxi Fare Prediction**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('/content/sample_data/archive (3).zip')

# %%
df
# Out:
#                                  key  fare_amount          pickup_datetime  \
# 0        2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1        2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2       2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3        2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4      2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
# ...                              ...          ...                      ...
# 49995    2013-06-12 23:25:15.0000004         15.0  2013-06-12 23:25:15 UTC
# 49996    2015-06-22 17:19:18.0000007          7.5  2015-06-22 17:19:18 UTC
# 49997   2011-01-30 04:53:00.00000063          6.9  2011-01-30 04:53:00 UTC
# 49998   2012-11-06 07:09:00.00000069          4.5  2012-11-06 07:09:00 UTC
# 49999    2010-01-13 08:13:14.0000007         10.9  2010-01-13 08:13:14 UTC
#
# ...

# %%
df.shape
# Out:
# (50000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   key                50000 non-null  object
#  1   fare_amount        50000 non-null  float64
#  2   pickup_datetime    50000 non-null  object
#  3   pickup_longitude   50000 non-null  float64
#  4   pickup_latitude    50000 non-null  float64
#  5   dropoff_longitude  50000 non-null  float64
#  6   dropoff_latitude   50000 non-null  float64
#  7   passenger_count    50000 non-null  int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 3.1+ MB

# %%
df.describe()
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  50000.000000      50000.000000     50000.000000       50000.000000
# mean      11.364171        -72.509756        39.933759         -72.504616
# std        9.685557         10.393860         6.224857          10.407570
# min       -5.000000        -75.423848       -74.006893         -84.654241
# 25%        6.000000        -73.992062        40.734880         -73.991152
# 50%        8.500000        -73.981840        40.752678         -73.980082
# 75%       12.500000        -73.967148        40.767360         -73.963584
# max      200.000000         40.783472       401.083332          40.851027
#
#        dropoff_latitude  passenger_count
# count      50000.000000     50000.000000
# mean          39.926251         1.667840
# std            6.014737         1.289195
# min          -74.006377         0.000000
# 25%           40.734372         1.000000
# 50%           40.753372         1.000000
# ...

# %%
x = df.drop(['key','passenger_count','dropoff_longitude','pickup_latitude', 'pickup_datetime'], axis=1)
y = df['fare_amount']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
r2 = r2_score(y_test, y_pred)
mse =  mean_squared_error(y_test, y_pred)

# %%
print("r2 :", r2)
# Out:
# r2 : 0.999972171945365

# %%
print("mse :", mse)
# Out:
# mse : 0.0025871996919999978

# %%
new = pd.DataFrame({"fare_amount":[3]})

# %%
predicted_fare = model.predict(new_prediction_data)
print("Predicted Fare Amount:", predicted_fare[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4928/2762708509.py in <cell line: 0>()
# ----> 1 predicted_fare = model.predict(new_prediction_data)
#       2 print("Predicted Fare Amount:", predicted_fare[0])
#
# NameError: name 'new_prediction_data' is not defined

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Fare Amount")
plt.ylabel("Predicted Fare Amount")
plt.title("Actual vs Predicted Fare Amount")
plt.show()
